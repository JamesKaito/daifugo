# %% [markdown]
# <a href="https://colab.research.google.com/github/JamesKaito/daifugo/blob/master/yolo_daifugo_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/'My Drive'/ColabNotebooks/
# Out:
# /content/drive/My Drive/ColabNotebooks

# %%
# !git clone https://github.com/pjreddie/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5901, done.
# remote: Total 5901 (delta 0), reused 0 (delta 0), pack-reused 5901
# Receiving objects: 100% (5901/5901), 6.16 MiB | 5.75 MiB/s, done.
# Resolving deltas: 100% (3915/3915), done.
# Checking out files: 100% (979/979), done.

# %%
# %cd darknet

# !cat Makefile
# !make
# Out:
# /content/drive/My Drive/ColabNotebooks/darknet
# GPU=1
# CUDNN=0
# OPENCV=0
# OPENMP=0
# DEBUG=0
#
# ARCH= -gencode arch=compute_30,code=sm_30 \
#       -gencode arch=compute_35,code=sm_35 \
#       -gencode arch=compute_50,code=[sm_50,compute_50] \
#       -gencode arch=compute_52,code=[sm_52,compute_52]
# #      -gencode arch=compute_20,code=[sm_20,sm_21] \ This one is deprecated?
#
# # This is what I use, uncomment if you know your arch and want to specify
# # ARCH= -gencode arch=compute_52,code=compute_52
#
# VPATH=./src/:./examples
# SLIB=libdarknet.so
# ALIB=libdarknet.a
# EXEC=darknet
# OBJDIR=./obj/
#
# CC=gcc
# CPP=g++
# NVCC=nvcc
# AR=ar
# ARFLAGS=rcs
# OPTS=-Ofast
# LDFLAGS= -lm -pthread
# COMMON= -Iinclude/ -Isrc/
# CFLAGS=-Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC
#
# ifeq ($(OPENMP), 1)
# CFLAGS+= -fopenmp
# endif
#
# ifeq ($(DEBUG), 1)
# OPTS=-O0 -g
# endif
#
# CFLAGS+=$(OPTS)
#
# ifeq ($(OPENCV), 1)
# COMMON+= -DOPENCV
# CFLAGS+= -DOPENCV
# ...

# %%
# !cat cfg/task/train.txt
# Out:
# cfg/task/data/scenes/val/039975226.jpg
# cfg/task/data/scenes/val/002089986.jpg
# cfg/task/data/scenes/val/010091499.jpg
# cfg/task/data/scenes/val/447624852.jpg
# cfg/task/data/scenes/val/817924535.jpg
# cfg/task/data/scenes/val/344078396.jpg
# cfg/task/data/scenes/val/731118529.jpg
# cfg/task/data/scenes/val/294957770.jpg
# cfg/task/data/scenes/val/074921437.jpg
# cfg/task/data/scenes/val/850238270.jpg
# cfg/task/data/scenes/val/240692462.jpg
# cfg/task/data/scenes/val/971660254.jpg
# cfg/task/data/scenes/val/129128403.jpg
# cfg/task/data/scenes/val/505942032.jpg
# cfg/task/data/scenes/val/995285890.jpg
# cfg/task/data/scenes/val/349514696.jpg
# cfg/task/data/scenes/val/228310929.jpg
# cfg/task/data/scenes/val/096880857.jpg
# cfg/task/data/scenes/val/986279050.jpg
# cfg/task/data/scenes/val/541777442.jpg
# cfg/task/data/scenes/val/210026366.jpg
# cfg/task/data/scenes/val/443182859.jpg
# cfg/task/data/scenes/val/232872801.jpg
# cfg/task/data/scenes/val/859508742.jpg
# ...

# %%
# !./darknet detector train ./cfg/task/datasets.data  cfg/task/yolov3-tiny.cfg cfg/task/backup/yolov3-tiny_75250.weights
# Out:
# Region 16 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000049, .5R: -nan, .75R: -nan,  count: 0
# Region 23 Avg IOU: 0.862414, Class: 0.996745, Obj: 0.865777, No Obj: 0.001332, .5R: 1.000000, .75R: 1.000000,  count: 7
# Region 16 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000004, .5R: -nan, .75R: -nan,  count: 0
# Region 23 Avg IOU: 0.866872, Class: 0.991664, Obj: 0.998330, No Obj: 0.001232, .5R: 1.000000, .75R: 1.000000,  count: 8
# Region 16 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000005, .5R: -nan, .75R: -nan,  count: 0
# Region 23 Avg IOU: 0.885717, Class: 0.996586, Obj: 0.974062, No Obj: 0.001604, .5R: 1.000000, .75R: 1.000000,  count: 7
# Region 16 Avg IOU: 0.728808, Class: 0.888830, Obj: 0.022735, No Obj: 0.000027, .5R: 1.000000, .75R: 0.000000,  count: 1
# Region 23 Avg IOU: 0.833272, Class: 0.818431, Obj: 0.801567, No Obj: 0.001169, .5R: 1.000000, .75R: 0.857143,  count: 7
# ...

# %%
# %cd darknet
# Out:
# /content/drive/My Drive/ColabNotebooks/darknet

# %%
# !make
# Out:
# make: Nothing to be done for 'all'.

# %%
# !chmod +x darknet

# %%
# !./darknet detector test cfg/task/datasets.data cfg/task/yolov3-tiny-det.cfg cfg/task/backup/yolov3-tiny_75250.weights cfg/task/data/scenes/val/num_00/001009637.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     16  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  16  0.319 BFLOPs
#     1 max          2 x 2 / 2   608 x 608 x  16   ->   304 x 304 x  16
#     2 conv     32  3 x 3 / 1   304 x 304 x  16   ->   304 x 304 x  32  0.852 BFLOPs
#     3 max          2 x 2 / 2   304 x 304 x  32   ->   152 x 152 x  32
#     4 conv     64  3 x 3 / 1   152 x 152 x  32   ->   152 x 152 x  64  0.852 BFLOPs
#     5 max          2 x 2 / 2   152 x 152 x  64   ->    76 x  76 x  64
#     6 conv    128  3 x 3 / 1    76 x  76 x  64   ->    76 x  76 x 128  0.852 BFLOPs
#     7 max          2 x 2 / 2    76 x  76 x 128   ->    38 x  38 x 128
#     8 conv    256  3 x 3 / 1    38 x  38 x 128   ->    38 x  38 x 256  0.852 BFLOPs
#     9 max          2 x 2 / 2    38 x  38 x 256   ->    19 x  19 x 256
#    10 conv    512  3 x 3 / 1    19 x  19 x 256   ->    19 x  19 x 512  0.852 BFLOPs
# ...

# %%
# !import opencv
# Out:
# backup	 examples	LICENSE       LICENSE.meta  obj        scripts
# cfg	 include	LICENSE.fuck  LICENSE.mit   python     src
# darknet  libdarknet.a	LICENSE.gen   LICENSE.v1    README.md
# data	 libdarknet.so	LICENSE.gpl   Makefile	    results

# %%
# !ls
# Out:
# backup		   include	  LICENSE.meta	   README.md
# cfg		   libdarknet.a   LICENSE.mit	   results
# darknet		   libdarknet.so  LICENSE.v1	   scripts
# data		   LICENSE	  Makefile	   src
# dtd		   LICENSE.fuck   obj		   Untitled0.ipynb
# dtd-r1.0.1.tar.gz  LICENSE.gen	  predictions.jpg
# examples	   LICENSE.gpl	  python

# %%
# !./darknet detector train ./cfg/task/datasets.data  cfg/task/yolov3-tiny.cfg
# Out:
# yolov3-tiny
# layer     filters    size              input                output
#     0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16  0.150 BFLOPs
#     1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16
#     2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32  0.399 BFLOPs
#     3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32
#     4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64  0.399 BFLOPs
#     5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64
#     6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128  0.399 BFLOPs
#     7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128
#     8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256  0.399 BFLOPs
#     9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256
#    10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512  0.399 BFLOPs
# ...

# %%
pwd
# Out:
# '/content/drive/My Drive/ColabNotebooks/data/scenes/val'

# %%
# %cd scenes/val
# Out:
# /content/drive/My Drive/ColabNotebooks/darknet/cfg/task/data/scenes/val

# %%
# !du
# Out:
# 4	./num_98-99
# 4	./num_96-97
# 4	./num_94-95
# 4	./num_92-93
# 4	./num_90-91
# 4	./num_88-89
# 4	./num_86-87
# 4	./num_84-85
# 4	./num_82-83
# 4	./num_80-81
# 4	./num_78-79
# 4	./num_76-77
# 4	./num_74-75
# 95585	./num_10
# 89936	./num_11
# 91897	./num_12
# 91097	./num_13
# 92404	./num_14
# 93151	./num_15
# 97460	./num_16
# 86730	./num_17
# 94528	./num_18
# 99230	./num_19
# 94319	./num_20
# 92454	./num_21
# 92234	./num_22
# 88302	./num_23
# 85381	./num_24
# 93340	./num_25
# 88752	./num_26
# 84030	./num_27
# 96592	./num_28
# 89484	./num_29
# 91396	./num_30
# 88093	./num_31
# 89448	./num_32
# 97572	./num_33
# 100932	./num_34
# 99032	./num_35
# 95236	./num_36
# 91019	./num_37
# 88859	./num_38
# 87515	./num_39
# 96615	./num_40
# 89007	./num_41
# 99647	./num_42
# 91671	./num_43
# 22210	./num_44
# 9791	./num_45
# 101512	./num_46
# 47078	./num_47
# 250	./num_48
# 65841	./num_49
# 89432	./num_50
# 91192	./num_51
# 89535	./num_52
# 98031	./num_53
# 102809	./num_54
# 87662	./num_55
# ...
